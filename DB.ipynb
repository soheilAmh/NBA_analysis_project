# %%
import sqlalchemy as db
import pandas as pd
from sqlalchemy import Column, Integer, ForeignKey, Table
from sqlalchemy.orm import relationship, declarative_base
from sqlalchemy import Column, Integer, String, create_engine
from sqlalchemy.orm import declarative_base, sessionmaker
from sqlalchemy.ext.declarative import declarative_base

# %%
engine = db.create_engine('mysql+pymysql://root:Str0ng!Pass_2025@localhost/schema_name')
# ساخت یک انجین (نوع دیتابیس + کانکتور :// نام کاربری : رمز عبور @ هاست/ اسم دیتابیس)

# %%
try:
    conn = engine.connect()
    print('connected successfully')
except:
    print('could not connect to Database')
# Out:
# connected successfully

# %%
Base = declarative_base()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_13956\3864161828.py:1: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %%
class Team(Base):
    __tablename__ = 'teams'
    Team_ID = Column(Integer,primary_key = True, autoincrement=True)
    Team = Column(String(4))
    Team_Full_Name = Column(String(255))
    Location = Column(String(255))
    Seasons = Column(Integer)
    Years_Active = Column(String(255))
    Win = Column(Integer)
    Loss = Column(Integer)
    Playoff = Column(Integer)
    Championships = Column(Integer)
    league_champions = relationship('League_Champions',back_populates='team')
    mvp = relationship('MVP',back_populates='team')
    top50 = relationship('Top_50',back_populates='team')

class Player(Base):
    __tablename__ = 'players'
    Player_ID = Column(Integer, primary_key = True, autoincrement=True)
    Player_Name = Column(String(100))
    Position = Column(String(100))
    Shoots = Column(String(10))
    Experience = Column(Integer)
    height = Column(String(10))
    weight = Column(Integer)
    Birth_date = Column(String(50))
    Hometown = Column(String(100))
    Country_State = Column(String(100))
    league_champions = relationship('League_Champions',back_populates='players')
    mvp = relationship('MVP',back_populates='players')
    top50 = relationship('Top_50',back_populates='players')


class League_Champions(Base):
    __tablename__ = 'league_champions'
    ID = Column(Integer,primary_key = True,autoincrement=True)
    Player_ID = Column(Integer, ForeignKey('players.Player_ID'), index=True)
    Team_ID = Column(Integer, ForeignKey('teams.Team_ID'), index=True)
    Shirt_No = Column(String(5))
    Name = Column(String(100))
    Experience = Column(String(3))
    Season = Column(String(50))
    Team_abv = Column(String(4))
    team = relationship('Team',back_populates='league_champions')
    players = relationship('Player',back_populates='league_champions')

class MVP(Base):
    __tablename__ = 'mvp'
    ID = Column(Integer,primary_key = True,autoincrement=True)
    Player_ID = Column(Integer, ForeignKey('players.Player_ID'), index=True)
    Team_ID = Column(Integer, ForeignKey('teams.Team_ID'), index=True)
    Rank = Column(Integer)
    Name = Column(String(100))
    Team_abv = Column(String(4))
    Season = Column(String(50))
    team = relationship('Team',back_populates='mvp')
    players = relationship('Player',back_populates='mvp')

class Top_50(Base):
    __tablename__ = 'top50'
    ID = Column(Integer,primary_key = True,autoincrement=True)
    Player_ID = Column(Integer, ForeignKey('players.Player_ID'), index=True)
    Team_ID = Column(Integer, ForeignKey('teams.Team_ID'), index=True)
    Rank = Column(Integer)
    Name = Column(String(100))
    Team_abv = Column(String(4))
    Season = Column(String(50))
    team = relationship('Team',back_populates='top50')
    players = relationship('Player',back_populates='top50')

# %%
Base.metadata.create_all(engine)

# %%
df = pd.read_csv(r"C:\Users\Asus\NBA_analysis_project\Players Information.csv")
df.to_sql("players", con=engine, if_exists="append", index=False)

df = pd.read_csv(r"C:\Users\Asus\NBA_analysis_project\Team Information.csv")
df.to_sql("teams", con=engine, if_exists="append", index=False)

df = pd.read_csv(r"C:\Users\Asus\NBA_analysis_project\League Champion.csv")
df.to_sql("league_champions", con=engine, if_exists="append", index=False)

df = pd.read_csv(r"C:\Users\Asus\NBA_analysis_project\mvp.csv")
df.to_sql("mvp", con=engine, if_exists="append", index=False)

df = pd.read_csv(r"C:\Users\Asus\NBA_analysis_project\top_50.csv")
df.to_sql("top50", con=engine, if_exists="append", index=False)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File ~\anaconda3\envs\quera\lib\site-packages\sqlalchemy\engine\base.py:1936, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1935     if not evt_handled:
# -> 1936         self.dialect.do_executemany(
#    1937             cursor,
#    1938             str_statement,
#    1939             effective_parameters,
#    1940             context,
#    1941         )
#    1942 elif not effective_parameters and context.no_parameters:
#
# File ~\anaconda3\envs\quera\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:196, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     189 def do_executemany(
#     190     self,
#     191     cursor: DBAPICursor,
#    (...)
#     194     context: Optional[ExecutionContext] = None,
#     195 ) -> None:
# --> 196     rowcount = cursor.executemany(statement, parameters)
#     197     if context is not None:
#
# File ~\anaconda3\envs\quera\lib\site-packages\pymysql\cursors.py:182, in Cursor.executemany(self, query, args)
#     181     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 182     return self._do_execute_many(
#     183         q_prefix,
#     184         q_values,
#     185         q_postfix,
#     186         args,
#     187         self.max_stmt_length,
#     188         self._get_db().encoding,
#     189     )
#     191 self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# File ~\anaconda3\envs\quera\lib\site-packages\pymysql\cursors.py:220, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     219     sql += v
# --> 220 rows += self.execute(sql + postfix)
#     221 self.rowcount = rows
#
# File ~\anaconda3\envs\quera\lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#
# File ~\anaconda3\envs\quera\lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#
# File ~\anaconda3\envs\quera\lib\site-packages\pymysql\connections.py:575, in Connection.query(self, sql, unbuffered)
#     574 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 575 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     576 return self._affected_rows
#
# File ~\anaconda3\envs\quera\lib\site-packages\pymysql\connections.py:826, in Connection._read_query_result(self, unbuffered)
#     825 else:
# --> 826     result.read()
#     827 self._result = result
#
# File ~\anaconda3\envs\quera\lib\site-packages\pymysql\connections.py:1203, in MySQLResult.read(self)
#    1202 try:
# -> 1203     first_packet = self.connection._read_packet()
#    1205     if first_packet.is_ok_packet():
#
# File ~\anaconda3\envs\quera\lib\site-packages\pymysql\connections.py:782, in Connection._read_packet(self, packet_type)
#     781         self._result.unbuffered_active = False
# --> 782     packet.raise_for_error()
#     783 return packet
#
# File ~\anaconda3\envs\quera\lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File ~\anaconda3\envs\quera\lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# IntegrityError: (1062, "Duplicate entry '1' for key 'players.PRIMARY'")
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 df = pd.read_csv(r"C:\Users\Asus\NBA_analysis_project\Players Information.csv")
# ----> 2 df.to_sql("players", con=engine, if_exists="append", index=False)
#       4 df = pd.read_csv(r"C:\Users\Asus\NBA_analysis_project\Team Information.csv")
#       5 df.to_sql("teams", con=engine, if_exists="append", index=False)
#
# File ~\anaconda3\envs\quera\lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\quera\lib\site-packages\pandas\core\generic.py:3106, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2908 """
#    2909 Write records stored in a DataFrame to a SQL database.
#    2910
#    (...)
#    3102 [(1,), (None,), (2,)]
#    3103 """  # noqa: E501
#    3104 from pandas.io import sql
# -> 3106 return sql.to_sql(
#    3107     self,
#    3108     name,
#    3109     con,
#    3110     schema=schema,
#    3111     if_exists=if_exists,
#    3112     index=index,
#    3113     index_label=index_label,
#    3114     chunksize=chunksize,
#    3115     dtype=dtype,
#    3116     method=method,
#    3117 )
#
# File ~\anaconda3\envs\quera\lib\site-packages\pandas\io\sql.py:844, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     839     raise NotImplementedError(
#     840         "'frame' argument should be either a Series or a DataFrame"
#     841     )
#     843 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 844     return pandas_sql.to_sql(
#     845         frame,
#     846         name,
#     847         if_exists=if_exists,
#     848         index=index,
#     849         index_label=index_label,
#     850         schema=schema,
#     851         chunksize=chunksize,
#     852         dtype=dtype,
#     853         method=method,
#     854         engine=engine,
#     855         **engine_kwargs,
#     856     )
#
# File ~\anaconda3\envs\quera\lib\site-packages\pandas\io\sql.py:2030, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2018 sql_engine = get_engine(engine)
#    2020 table = self.prep_table(
#    2021     frame=frame,
#    2022     name=name,
#    (...)
#    2027     dtype=dtype,
#    2028 )
# -> 2030 total_inserted = sql_engine.insert_records(
#    2031     table=table,
#    2032     con=self.con,
#    2033     frame=frame,
#    2034     name=name,
#    2035     index=index,
#    2036     schema=schema,
#    2037     chunksize=chunksize,
#    2038     method=method,
#    2039     **engine_kwargs,
#    2040 )
#    2042 self.check_case_sensitive(name=name, schema=schema)
#    2043 return total_inserted
#
# File ~\anaconda3\envs\quera\lib\site-packages\pandas\io\sql.py:1579, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1577 if re.search(msg, err_text):
#    1578     raise ValueError("inf cannot be used with MySQL") from err
# -> 1579 raise err
#
# File ~\anaconda3\envs\quera\lib\site-packages\pandas\io\sql.py:1570, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1567 from sqlalchemy import exc
#    1569 try:
# -> 1570     return table.insert(chunksize=chunksize, method=method)
#    1571 except exc.StatementError as err:
#    1572     # GH34431
#    1573     # https://stackoverflow.com/a/67358288/6067848
#    1574     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1575     )|inf can not be used with MySQL"""
#
# File ~\anaconda3\envs\quera\lib\site-packages\pandas\io\sql.py:1121, in SQLTable.insert(self, chunksize, method)
#    1118     break
#    1120 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1121 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1122 # GH 46891
#    1123 if num_inserted is not None:
#
# File ~\anaconda3\envs\quera\lib\site-packages\pandas\io\sql.py:1012, in SQLTable._execute_insert(self, conn, keys, data_iter)
#    1000 """
#    1001 Execute SQL statement inserting data
#    1002
#    (...)
#    1009    Each item contains a list of values to be inserted
#    1010 """
#    1011 data = [dict(zip(keys, row)) for row in data_iter]
# -> 1012 result = conn.execute(self.table.insert(), data)
#    1013 return result.rowcount
#
# File ~\anaconda3\envs\quera\lib\site-packages\sqlalchemy\engine\base.py:1419, in Connection.execute(self, statement, parameters, execution_options)
#    1417     raise exc.ObjectNotExecutableError(statement) from err
#    1418 else:
# -> 1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# File ~\anaconda3\envs\quera\lib\site-packages\sqlalchemy\sql\elements.py:526, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     524     if TYPE_CHECKING:
#     525         assert isinstance(self, Executable)
# --> 526     return connection._execute_clauseelement(
#     527         self, distilled_params, execution_options
#     528     )
#     529 else:
#     530     raise exc.ObjectNotExecutableError(self)
#
# File ~\anaconda3\envs\quera\lib\site-packages\sqlalchemy\engine\base.py:1641, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1629 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1630     "compiled_cache", self.engine._compiled_cache
#    1631 )
#    1633 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1634     dialect=dialect,
#    1635     compiled_cache=compiled_cache,
#    (...)
#    1639     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1640 )
# -> 1641 ret = self._execute_context(
#    1642     dialect,
#    1643     dialect.execution_ctx_cls._init_compiled,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     execution_options,
#    1647     compiled_sql,
#    1648     distilled_parameters,
#    1649     elem,
#    1650     extracted_params,
#    1651     cache_hit=cache_hit,
#    1652 )
#    1653 if has_events:
#    1654     self.dispatch.after_execute(
#    1655         self,
#    1656         elem,
#    (...)
#    1660         ret,
#    1661     )
#
# File ~\anaconda3\envs\quera\lib\site-packages\sqlalchemy\engine\base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~\anaconda3\envs\quera\lib\site-packages\sqlalchemy\engine\base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~\anaconda3\envs\quera\lib\site-packages\sqlalchemy\engine\base.py:2355, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2353 elif should_wrap:
#    2354     assert sqlalchemy_exception is not None
# -> 2355     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2356 else:
#    2357     assert exc_info[1] is not None
#
# File ~\anaconda3\envs\quera\lib\site-packages\sqlalchemy\engine\base.py:1936, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1934                 break
#    1935     if not evt_handled:
# -> 1936         self.dialect.do_executemany(
#    1937             cursor,
#    1938             str_statement,
#    1939             effective_parameters,
#    1940             context,
#    1941         )
#    1942 elif not effective_parameters and context.no_parameters:
#    1943     if self.dialect._has_events:
#
# File ~\anaconda3\envs\quera\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:196, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     189 def do_executemany(
#     190     self,
#     191     cursor: DBAPICursor,
#    (...)
#     194     context: Optional[ExecutionContext] = None,
#     195 ) -> None:
# --> 196     rowcount = cursor.executemany(statement, parameters)
#     197     if context is not None:
#     198         cast(MySQLExecutionContext, context)._rowcount = rowcount
#
# File ~\anaconda3\envs\quera\lib\site-packages\pymysql\cursors.py:182, in Cursor.executemany(self, query, args)
#     180     q_postfix = m.group(3) or ""
#     181     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 182     return self._do_execute_many(
#     183         q_prefix,
#     184         q_values,
#     185         q_postfix,
#     186         args,
#     187         self.max_stmt_length,
#     188         self._get_db().encoding,
#     189     )
#     191 self.rowcount = sum(self.execute(query, arg) for arg in args)
#     192 return self.rowcount
#
# File ~\anaconda3\envs\quera\lib\site-packages\pymysql\cursors.py:220, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     218         sql += b","
#     219     sql += v
# --> 220 rows += self.execute(sql + postfix)
#     221 self.rowcount = rows
#     222 return rows
#
# File ~\anaconda3\envs\quera\lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\anaconda3\envs\quera\lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~\anaconda3\envs\quera\lib\site-packages\pymysql\connections.py:575, in Connection.query(self, sql, unbuffered)
#     573     sql = sql.encode(self.encoding, "surrogateescape")
#     574 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 575 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     576 return self._affected_rows
#
# File ~\anaconda3\envs\quera\lib\site-packages\pymysql\connections.py:826, in Connection._read_query_result(self, unbuffered)
#     824     result.init_unbuffered_query()
#     825 else:
# --> 826     result.read()
#     827 self._result = result
#     828 if result.server_status is not None:
#
# File ~\anaconda3\envs\quera\lib\site-packages\pymysql\connections.py:1203, in MySQLResult.read(self)
#    1201 def read(self):
#    1202     try:
# -> 1203         first_packet = self.connection._read_packet()
#    1205         if first_packet.is_ok_packet():
#    1206             self._read_ok_packet(first_packet)
#
# File ~\anaconda3\envs\quera\lib\site-packages\pymysql\connections.py:782, in Connection._read_packet(self, packet_type)
#     780     if self._result is not None and self._result.unbuffered_active is True:
#     781         self._result.unbuffered_active = False
# --> 782     packet.raise_for_error()
#     783 return packet
#
# File ~\anaconda3\envs\quera\lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File ~\anaconda3\envs\quera\lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# IntegrityError: (pymysql.err.IntegrityError) (1062, "Duplicate entry '1' for key 'players.PRIMARY'")
# [SQL: INSERT INTO players (`Player_ID`, `Player_Name`, `Position`, `Shoots`, `Experience`, `Height`, `Weight`, `Birth_date`, `Hometown`, `Country_State`) VALUES (%(Player_ID)s, %(Player_Name)s, %(Position)s, %(Shoots)s, %(Experience)s, %(Height)s, %(Weight)s, %(Birth_date)s, %(Hometown)s, %(Country_State)s)]
# [parameters: [{'Player_ID': 1, 'Player_Name': 'Markieff Morris', 'Position': 'Power Forward    ', 'Shoots': 'Right', 'Experience': 14, 'Height': '6\'9"', 'Weight': 245, 'Birth_date': 'September 2,\r\n 1989', 'Hometown': 'Philadelphia', 'Country_State': 'Pennsylvania'}, {'Player_ID': 2, 'Player_Name': 'Jack White', 'Position': 'Small Forward    ', 'Shoots': 'Right', 'Experience': 2, 'Height': '6\'7"', 'Weight': 225, 'Birth_date': 'August 5,\r\n 1997', 'Hometown': 'Traralgon', 'Country_State': 'Australia'}, {'Player_ID': 3, 'Player_Name': 'Bones Hyland', 'Position': 'Point Guard and Shooting Guard    ', 'Shoots': 'Right', 'Experience': 4, 'Height': '6\'2"', 'Weight': 173, 'Birth_date': 'September 14,\r\n 2000', 'Hometown': 'Wilmington', 'Country_State': 'Delaware'}, {'Player_ID': 4, 'Player_Name': 'Bobby Portis', 'Position': 'Power Forward and Center    ', 'Shoots': 'Right', 'Experience': 10, 'Height': '6\'10"', 'Weight': 250, 'Birth_date': 'February 10,\r\n 1995', 'Hometown': 'Little', 'Country_State': 'Arkansas'}, {'Player_ID': 5, 'Player_Name': 'Shai Gilgeous-Alexander', 'Position': 'Point Guard and Shooting Guard    ', 'Shoots': 'Right', 'Experience': 7, 'Height': '6\'6"', 'Weight': 200, 'Birth_date': 'July 12,\r\n 1998', 'Hometown': 'Toronto', 'Country_State': 'Ontario'}, {'Player_ID': 6, 'Player_Name': 'Khris Middleton', 'Position': 'Small Forward and Shooting Guard    ', 'Shoots': 'Right', 'Experience': 13, 'Height': '6\'7"', 'Weight': 222, 'Birth_date': 'August 12,\r\n 1991', 'Hometown': 'Charleston', 'Country_State': 'South Carolina'}, {'Player_ID': 7, 'Player_Name': 'JD Davison', 'Position': 'Shooting Guard and Point Guard    ', 'Shoots': 'Right', 'Experience': 3, 'Height': '6\'1"', 'Weight': 195, 'Birth_date': 'October 3,\r\n 2002', 'Hometown': 'Montgomery', 'Country_State': 'Alabama'}, {'Player_ID': 8, 'Player_Name': 'Jalen Williams', 'Position': 'Shooting Guard and Power Forward    ', 'Shoots': 'Right', 'Experience': 3, 'Height': '6\'6"', 'Weight': 220, 'Birth_date': 'April 14,\r\n 2001', 'Hometown': 'Denver', 'Country_State': 'Colorado'}  ... displaying 10 of 203 total bound parameter sets ...  {'Player_ID': 202, 'Player_Name': 'Rajon Rondo', 'Position': 'Point Guard    ', 'Shoots': 'Right', 'Experience': 16, 'Height': '6\'1"', 'Weight': 180, 'Birth_date': 'February 22,\r\n 1986', 'Hometown': 'Louisville', 'Country_State': 'Kentucky'}, {'Player_ID': 203, 'Player_Name': 'Tobias Harris', 'Position': 'Power Forward and Small Forward    ', 'Shoots': 'Right', 'Experience': 14, 'Height': '6\'8"', 'Weight': 226, 'Birth_date': 'July 15,\r\n 1992', 'Hometown': 'Islip', 'Country_State': 'New York'}]]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
